# %%
import boto3
import pandas as pd
from logging import log, CRITICAL, ERROR, INFO, DEBUG, WARN
from datetime import datetime, timedelta
pd.set_option('display.max_rows', None)

# %% [markdown]
# Setup Environment
# Verify that you have set AWS credentials in your user data
# Location: ~/.aws/credentials
# Verify you are in correct sandbox / production setting
# Format:
#
# [default]
# aws_access_key_id=XXXXXXX
# aws_secret_access_key=XXXXX

# %%
def check_response(resp):
    status = resp['ResponseMetadata']['HTTPStatusCode']
    if status != 200:
        log(ERROR, resp)  

SANDBOX = False
if SANDBOX:
    sandbox_ep = 'https://mturk-requester-sandbox.us-east-1.amazonaws.com'
    mturk = boto3.client('mturk', region_name = 'us-east-1', endpoint_url = sandbox_ep)
else:
    mturk = boto3.client('mturk', region_name = 'us-east-1')

def get_balance():
    resp = mturk.get_account_balance()
    check_response(resp)
    balance = resp['AvailableBalance']
    return balance
    
def print_env():
    print("Available Balance: ", get_balance())
    if SANDBOX:
        print("SANDBOX Environment")
    else:
        log(WARN, "PRODUCTION Environment")

# %%
print_env()#when I started my trap reminder task
# Out:
# WARNING:root:PRODUCTION Environment
# Available Balance:  331.39

# %% [markdown]
# ### Who has our qualification for a certain task

# %%
def check_who_has_qual(qual_id):
    res = mturk.list_workers_with_qualification_type(QualificationTypeId=qual_id,MaxResults=100)
    all_workers = []
    for rec in res['Qualifications']:
        print(rec['WorkerId'], rec["GrantTime"])
        all_workers.append(rec['WorkerId'])
    return all_workers

# %%
qual_trap_granted = '3N2J8SDS8LBYPCUOGA88O5UTDU9XYB'
qual_prev_workers = '3BELWBFOS6JPVRXFLT6GVTT3ITD78C'
qual_in_training = '3BVFUZHH5MI7NI1FAMZW4F97L5DINY'
qual_in_training_late = '31GBYMVNTPCPJC37L5IG0G9MXWOYE9' #late workers
prod_gr_1 = '3HKJJ33FJ4GQMSLBB8YRFK2YILFK67'
prod_gr_2 = '37PDZ31J6CH6ZW4TMPLKTKQ4SXPGVR'
prod_gr_3 = '3N54K5T7LDFNU7U3HSWTLQA4L4LYZ7'
prod_gr_4 = '33DXTGLH9F2S00V95Y514YCD24K3PM'
prod_gr_5 = '38T2WS02O0BARM1Z1ZAMWH3A4KVUTW'
valentina = '3YJFRJA91LRKWWZCLW9F85034IOZDE'
consol = '3BELWBFOS6JPVRXFLT6GVTT3JZN870'
prod_consol = '33MAVWP2GR93U8N4YD73RI88DT0ZL8'

# %%
def remove_qual(qual_id, workers):
    for wrk in workers:
        mturk.disassociate_qualification_from_worker(WorkerId=wrk, QualificationTypeId=qual_id)
        
def give_qual(qual_id, workers):
    for wrk in workers:
        mturk.associate_qualification_with_worker(WorkerId=wrk, QualificationTypeId=qual_id, IntegerValue=1)

# %%
# First run the check qualification cell, then the groups

# %%
grp1 = ['A1KGCOR8OXYR72']
grp2 = ['A98E8M4QLI9RS']
grp3 = ['A3B7TNVOISSZ2O']
grp4 = ['AZLZA0Q87TJZO','A2EJ7U3TZAKROG']
grp5 = ['A1FS8SBR4SDWYG','AZLZA0Q87TJZO']

# %%
give_qual(prod_consol, consolg)

# %%
give_qual(prod_gr_1, grp1)

# %%
give_qual(prod_gr_2, grp2) #consolidation

# %%
give_qual(prod_gr_3, grp3)

# %%
give_qual(prod_gr_4, grp4)

# %%
give_qual(consol, ['A3B7TNVOISSZ2O'])

# %%
check_who_has_qual(consol)
# Out:
# A1KGCOR8OXYR72 2021-04-16 00:34:38+03:00
# A2EJ7U3TZAKROG 2021-04-16 00:34:39+03:00
# A3B7TNVOISSZ2O 2021-04-25 20:52:30+03:00
# A98E8M4QLI9RS 2021-04-16 00:34:38+03:00
# ['A1KGCOR8OXYR72', 'A2EJ7U3TZAKROG', 'A3B7TNVOISSZ2O', 'A98E8M4QLI9RS']

# %%
print("Group1")
check_who_has_qual(prod_gr_1)
print("Group2")
check_who_has_qual(prod_gr_2)
print("Group3")
check_who_has_qual(prod_gr_3)
print("Group4")
check_who_has_qual(prod_gr_4)
print("Group5")
check_who_has_qual(prod_gr_5)
# Out:
# Group1
# A1KGCOR8OXYR72 2021-04-25 20:48:58+03:00
# Group2
# A98E8M4QLI9RS 2021-04-25 20:48:58+03:00
# Group3
# A3B7TNVOISSZ2O 2021-04-25 20:48:59+03:00
# Group4
# A2EJ7U3TZAKROG 2021-04-25 20:48:59+03:00
# Group5
# AZLZA0Q87TJZO 2021-04-19 20:52:09+03:00
# A1FS8SBR4SDWYG 2021-04-19 20:52:09+03:00
# ['AZLZA0Q87TJZO', 'A1FS8SBR4SDWYG']

# %%
remove_qual(prod_gr_4,["AZLZA0Q87TJZO"])

# %% [markdown]
# ### On sandbox

# %%
check_who_has_qual(sandbox_qual)

# %%
remove_qual(sandbox_qual, ['A175DRQDVKWQA7'])

# %%
give_qual(sandbox_qual, ['A3UENPLNM9AQBK'])

# %%
check_who_has_qual(sandbox_qual)
# Out:
# A3UENPLNM9AQBK 2021-01-07 15:20:49+02:00
# A175DRQDVKWQA7 2021-01-07 15:19:39+02:00

# %% [markdown]
# ### Give workers  a qualification

# %%
workers = ["A175DRQDVKWQA7"]

# %%
prev_work_qual = '3BELWBFOS6JPVRXFLT6GVTT3ITD78C' #qa qualification

# %%
for item in workers:
    mturk.associate_qualification_with_worker(WorkerId=item, QualificationTypeId=prev_work_qual, IntegerValue=1)

# %% [markdown]
# ### check we did it correctly

# %%
res = mturk.list_workers_with_qualification_type(QualificationTypeId="3T0EA825IIG57D2Q3MWOV7TVAYGQQ6")
for rec in res['Qualifications']:
    print(rec['WorkerId'], rec["GrantTime"])
# Out:
# A175DRQDVKWQA7 2020-04-06 11:11:57+03:00

# %% [markdown]
# cool

# %%
mturk.disassociate_qualification_from_worker(WorkerId="A175DRQDVKWQA7", QualificationTypeId="3T0EA825IIG57D2Q3MWOV7TVAYGQQ6")
# Out:
# {'ResponseMetadata': {'RequestId': 'e7a29a75-464f-4a9a-a276-b40945cb899d',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'e7a29a75-464f-4a9a-a276-b40945cb899d',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '2',
#    'date': 'Fri, 25 Dec 2020 16:25:36 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Checking status of ongoing hits

# %%
def hits_df(hits):
    cols = ['h_id', 't_id', 'status', 'review_status', 'reward', 'title', 'create_date', 'expire_date', 
             'duration_sec', 'auto_approve_sec',
             'assign_available', 'assign_completed','assign_pending', 'MaxAssignments', 
             'id', 'hit_type', 'hit_group_id', 'Keywords', 'Description']
    if not len(hits):
        return pd.DataFrame(columns=cols)
    
    df = pd.DataFrame.from_records(hits)
    df.drop(['QualificationRequirements', 'Question'], axis='columns', inplace=True)

    df.rename(columns={
        'HITId': 'id',
        'HITTypeId': 'hit_type',
        'HITGroupId': 'hit_group_id',
        'HITStatus': 'status',
        'HITReviewStatus': 'review_status',
        'AssignmentDurationInSeconds':'duration_sec', 
        'AutoApprovalDelayInSeconds': 'auto_approve_sec', 
        'NumberOfAssignmentsAvailable': 'assign_available',
        'NumberOfAssignmentsCompleted': 'assign_completed',
        'NumberOfAssignmentsPending': 'assign_pending',
        'CreationTime': 'create_date',
        'Expiration': 'expire_date',
        'Reward': 'reward',
        'Title': 'title'}, inplace=True)

    df['h_id'] = df.id.str.slice(-5)
    df['t_id'] = df.hit_type.str.slice(-5)
    df = df[['h_id', 't_id', 'status', 'review_status', 'reward', 'title', 'create_date', 'expire_date', 
             'duration_sec', 'auto_approve_sec',
             'assign_available', 'assign_completed','assign_pending', 'MaxAssignments', 
             'id', 'hit_type', 'hit_group_id', 'Keywords', 'Description']]
    return df

# %%
def refresh():
    print_env()
    hits = []
    resp = mturk.list_hits(MaxResults=100)
    
    has_more = resp["NextToken"]    
    while resp["NumResults"] > 0:
        hits.extend(resp['HITs'])
        next_tok = resp["NextToken"]
        print("Returned: ", resp["NumResults"], " results")
        print("Trying next token: ", next_tok)        
        resp = mturk.list_hits(MaxResults=100, NextToken=next_tok)
            
    hits = hits_df(hits)
    return hits

# %%
hits = refresh()
# Out:
# WARNING:root:PRODUCTION Environment
# Available Balance:  2810.97
# Returned:  100  results
# Trying next token:  p2:IkBCy1drkfM/OCxrhuAygKgL848DLaTxTDvLQcFtVY7KPuvbQTzi05wiT7o24o4=
# Returned:  100  results
# Trying next token:  p2:IZCGP+RgHydpSiuxiFCii5plbP0RqJnhCtAEmF7Am5niTf6jhxz4Q0UvWDQUPAs=
# Returned:  100  results
# Trying next token:  p2:UJH01Y13kd1N4+KAP1cDmsZdg7OXy2BqkpWDbkyaWO5gvcknH8nJGKSP7ucSZdk=
# Returned:  100  results
# Trying next token:  p2:/AvEILk/BfVngyRp6uCT3sYWp/QkTK6zIkWCWaQt0WAEGEcOvAMpOq7z726FDuM=
# Returned:  100  results
# Trying next token:  p2:Q6joIRlLnHHpRwT3Pr3PrUW7FLoUtFwuR+dPLRjKkdi5f771nfi78Lczr4ESwP4=
# Returned:  100  results
# Trying next token:  p2:v0PvIARd7adigqJbUr+2ox0Z9Vjtnp/HVNzogMhc1Yz+vXKA6ORdatKN4jbhAVA=
# Returned:  100  results
# Trying next token:  p2:Jz1iWutm+jh/i0iICX/xkqwQLoa0r4LUJ/OZrKc+dVh43PBjewBjS2XvMut5F9s=
# Returned:  100  results
# Trying next token:  p2:Yi5NbroWfhk1AfUZldF4b5ohd5nFI5s/2FflqImS9JoCpRN4DJa9v16B4Epe/jo=
# Returned:  100  results
# Trying next token:  p2:tS3iNwdzNNSZ7gDHWR0hDgIDd0drbcrljvjy8tWkTr6IOFoVcXHGuVwpT0VZEBd1
# Returned:  100  results
# Trying next token:  p2:1cARX9GjtMGxIZbNfHOOaIbjDEljVbtf+Fiy+KfoeK2DOnkWs8nh3pnX6KjGMYBM
# Returned:  100  results
# Trying next token:  p2:bQjHThDI4cPqMhjpXCsBdfxcGbUGqrfSV0rs8eY7dOYgqk2HjOJgjlMx2pvkObfi
# Returned:  100  results
# Trying next token:  p2:7J9q9FYjDdGvx2PiBeES19MCtuXnQj0mePpSJAbfWsuVph2Rqdsshmcx4tVmmepF
# Returned:  100  results
# Trying next token:  p2:8ejMi7mgYsxYG7U9vWWlbGuYJkh8Ie5ZIjV144T4VsCB7Yp3RZnmYoOKpVAtRRJW
# Returned:  100  results
# Trying next token:  p2:xezShKTOh0folbubQLUsyFbHJbE5rX+4acC8oe9LrYNs0JRkjVs5uYC4NFagvdlo
# Returned:  100  results
# Trying next token:  p2:AnyO3ir9dSir1NxgcKZbwnztOYfesikaYjh5zqloX9NvWLxyrnOg+vYA5oB3eknr
# Returned:  100  results
# Trying next token:  p2:HXmMCVZ2DQnUj+uhYtKxIWUcr7cnkhDFqEt8f/QLuoVRbByMA4SBLSXulyLnOgcZ
# Returned:  100  results
# Trying next token:  p2:ePHjeuS/W/Y7X+2yHg2eLsB2lmfmzWab/9oEcxBmBdmZg8bUMrYij8HWJspe9WXP
# Returned:  100  results
# Trying next token:  p2:SmFZ3Z9GNhBcY0dTipgxWpMLqa0S9r+T4gew3Pq8t+ADrjinUDggv5Wrlh3C/W06
# Returned:  100  results
# Trying next token:  p2:vUD7WgwOaiaNvf8Ttd0nYX79lEJ6u4OMRz7dhI2K8XmgomttXxNCktL1UXzwQhUk
# Returned:  100  results
# Trying next token:  p2:8l9mm3GPmvK9wMh8WAlwlAqwM3EzQ7v5eK4ZJG2zFdo7Bd8KY/jTw0pQUuDcJBdW
# Returned:  100  results
# Trying next token:  p2:BMD/er9FMCDueOkxZBEOaukto7C+cD3eInsjOQWaAkSEizoLpix7fA3U73a49KHv
# Returned:  100  results
# Trying next token:  p2:DnNrk4EG86CBYu+Lyi30UgaY6mNr6nz06OGi0XkSlT6haHcYXZKuVNxAwl6fXoGQ
# Returned:  100  results
# Trying next token:  p2:ijCW2aSf3oqLO8ikD4O9xy+mvHGUlABLN5tJrSiVW7ajQuSGciURLTno/pZ/pL5d
# Returned:  80  results
# Trying next token:  p2:xYmrLJhQP0BeNhTqcsh8n1XmivUtIh+OxtKX2I5iMUv/IPVtkdKb2JUvU4+TNxSO

# %%
hits.status.value_counts()
# Out:
# Reviewable    2372
# Assignable       8
# Name: status, dtype: int64

# %%
hits.columns
# Out:
# Index(['h_id', 't_id', 'status', 'review_status', 'reward', 'title',
#        'create_date', 'expire_date', 'duration_sec', 'auto_approve_sec',
#        'assign_available', 'assign_completed', 'assign_pending',
#        'MaxAssignments', 'id', 'hit_type', 'hit_group_id', 'Keywords',
#        'Description'],
#       dtype='object')

# %%
#hits.groupby(["title", "hit_type", 'status' ]).size().rename("hit_count").reset_index().sort_values("hit_count", ascending=False)
hits.groupby(["title", "hit_type", "status"]).size().rename("hit_count").reset_index().sort_values("hit_count", ascending=False)
# Out:
#                                                 title  \
# 46                            Ohad NLI Color-New Full
# 56                  Rewrite Questions Control Overlap
# 51                         Ohad NLI Trademarks - Full
# 16  Hexagon Board tasks (drawing only) (P02R01-2a)...
# 19  Hexagon Board tasks (drawing only) (P02R01-2d)...
# 47                             Ohad NLI Hypernymy-New
# 53                Rewrite Questions & Control Overlap
# 52                Rewrite Questions & Control Overlap
# 61    Rewrite Questions Control Overlap (Low to High)
# 55                  Rewrite Questions Control Overlap
# 59                  Rewrite Questions Control Overlap
# 62    Rewrite Questions Control Overlap (Low to High)
# 49                         Ohad NLI Hypernymy-New (6)
# 60    Rewrite Questions Control Overlap (Low to High)
# 50             Ohad NLI Hypernymy-New - Qualification
# 57                  Rewrite Questions Control Overlap
# 17  Hexagon Board tasks (drawing only) (P02R01-2b)...
# 48                         Ohad NLI Hypernymy-New (3)
# 54                  Rewrite Questions Control Overlap
# 18  Hexagon Board tasks (drawing only) (P02R01-2c)...
# 58                  Rewrite Questions Control Overlap
# 24  Hexagon Board tasks (writing and drawing) (P02...
# 21  Hexagon Board tasks (drawing only) (P02R01-2f)...
# 0   Aligning Related Question-Answer Sets in Sente...
# 1   Aligning Related Question-Answer Sets in Sente...
# 2   Aligning Related Question-Answer Sets in Sente...
# 34  Hexagon Board tasks (writing and drawing) FOR ...
# 39  Hexagon Board tasks (writing and drawing) FOR ...
# 26  Hexagon Board tasks (writing and drawing) (P02...
# 27  Hexagon Board tasks (writing and drawing) (P02...
# 28  Hexagon Board tasks (writing and drawing) (P02...
# 29  Hexagon Board tasks (writing and drawing) (P02...
# 25  Hexagon Board tasks (writing and drawing) (P02...
# 42  Hexagon Board tasks (writing and drawing) FOR ...
# 41  Hexagon Board tasks (writing and drawing) FOR ...
# 35  Hexagon Board tasks (writing and drawing) FOR ...
# 36  Hexagon Board tasks (writing and drawing) FOR ...
# 37  Hexagon Board tasks (writing and drawing) FOR ...
# 40  Hexagon Board tasks (writing and drawing) FOR ...
# 43  Hexagon Board tasks (writing and drawing) FOR ...
# 38  Hexagon Board tasks (writing and drawing) FOR ...
# 30  Hexagon Board tasks (writing and drawing) (P02...
# 6                       CDC Production Review B2 HITs
# 4                      CDC Production Annotation HITs
# 5                       CDC Production Review A2 HITs
# 31  Hexagon Board tasks (writing and drawing) (P02...
# 22  Hexagon Board tasks (drawing only) (P02R01-2g)...
# 44           NLI Logic Games Colors-New (Preliminary)
# 45           NLI Logic Games Trademarks (Preliminary)
# 20  Hexagon Board tasks (drawing only) (P02R01-2e)...
# 8                  CDC Qualification Annotation HIT 2
# 32  Hexagon Board tasks (writing and drawing) (P02...
# 3                                      CDC Guided HIT
# 33  Hexagon Board tasks (writing and drawing) (P02...
# 7                    CDC Qualification Annotation HIT
# 9        CDC Qualification Review HIT (Andrea Atwood)
# 10         CDC Qualification Review HIT (Annie Chase)
# 11       CDC Qualification Review HIT (Ashley Trunko)
# 12       CDC Qualification Review HIT (Gillian Kirby)
# 13                                   CDC Tutorial HIT
# 14        Hexagon Board compensation HIT (P02R02)(RT)
# 15       Hexagon Board compensation HIT (P02R02b)(RT)
# 23  Hexagon Board tasks (drawing only) (P02R01-2h)...
#
#                           hit_type      status  hit_count
# 46  3T5H7R2NRCLA85LE47248YWG7AZZWD  Reviewable        324
# 56  3CM00QMEULN8KV13225TB03L25GW6V  Reviewable        250
# 51  3QMCR5SRRUVY8M7P498WSZXJCQX4GW  Reviewable        200
# 16  3HID22PG0DC0S4ZVJ530Q3GZDLPVSK  Reviewable        193
# 19  31RF5NHNFOAX2FO7SIMA7TVOWNL1LY  Reviewable        107
# 47  3QH037L2CM697XD6SFM5R557YR5WAQ  Reviewable        100
# 53  3EKS5N8MHTGS7A19FQYP77N8SX1ZI2  Reviewable        100
# 52  34WBNEQO09S9IB1CZZCVZHHWORABRQ  Reviewable        100
# 61  3CS3U1VE5JPKZ3YFG8FB5AQ9JP3S0G  Reviewable        100
# 55  35RL0GHNS7TG0O4ITFK91L9APFCGEZ  Reviewable         80
# 59  3ZKEGEY9TKU0SAQPDUA5DWUC8AYXXU  Reviewable         70
# 62  3FJMTJX97NPBDIY01X91TB6UAMJ6A0  Reviewable         70
# 49  3CQ0L5JRM83Z565DDK9Q50A1YQZUER  Reviewable         68
# 60  31OMQ2YLPM6AQGMXBKSPD648E3T66A  Reviewable         68
# 50  3QH037L2CM697XD6SFM5R557YR9AW8  Reviewable         66
# 57  3O8UG586S9MJTCKHQ32M0IBW8DN49Q  Reviewable         60
# 17  3HD129RETC3WBTIJSWZAG8KUICZ46Z  Reviewable         55
# 48  3AXXFYZYN4YCN9B3NX1BPXHX8KTG6P  Reviewable         53
# 54  32TI4QMY9C91UPNA3FYL4MA21XDTU1  Reviewable         50
# 18  3T2WVEM8EKHL3ALZ3PEJBDG5Z93WXD  Reviewable         39
# 58  3VL3OSLWYGZHGNA6HRPUU1QG05NG1T  Reviewable         30
# 24  3F2T062I4XHY0W3BFC6R54HG8C04MV  Reviewable         29
# 21  3LOAKXD6JBQ7PEDW9QEL0PNHRPLRE6  Reviewable         21
# 0   3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable          8
# 1   3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Reviewable          7
# 2   3XA69K8C5XODD906WWTCG4C4U12W1D  Reviewable          7
# 34  3EH3OJYIRZYDW2867G4TC2QN9VNYA1  Reviewable          6
# 39  3Z1ME8JRSHCPV312L7RMG6I9VO9OCI  Reviewable          6
# 26  3FE8IUW5NG8KQIQT7YYDHQMCU5799X  Reviewable          6
# 27  3YBVJZAYKJTEY3HV4JUYLTLN3DYYM9  Reviewable          6
# 28  3IV76CXOO3AWT83AJE3F3M52LQM9DE  Reviewable          6
# 29  32KI9HN0SH90L5B11WEBYGR79ET1U7  Reviewable          6
# 25  3VU3J1KUFBZIP7MFJA94079BSP4TG7  Reviewable          6
# 42  370L63GT3CM2N84OYTD62O9ICMF183  Reviewable          6
# 41  3WZSTMTM4ERS2KR4J4W6T0E6M3SIYP  Reviewable          6
# 35  32HMK6WX8ZMISCK4UMOSGMX656N3KG  Reviewable          6
# 36  3MCSZWKJ0Y7FJUL05EG8IADR6RP16H  Reviewable          6
# 37  3XL0AZPMI5CSGFEI0KJQ5BD9APRQCS  Reviewable          6
# 40  35EE6WR8LG3YNUZ5OOL0OODN12917G  Reviewable          6
# 43  37V5OWJ68WQDOR45ZW6ZEH24LQKLVX  Reviewable          5
# 38  3SC1WC0NS376LY9W77VR5MCRD39OBB  Reviewable          5
# 30  3RL1BYM291LGCZ20S10T3UV6ZFJ79J  Reviewable          4
# 6   3496Z8XDHLJ21ZYXQJPBKWD17QV2IU  Reviewable          3
# 4   3VTTFELP3T823WCCDLBUR4JU48MOZC  Reviewable          3
# 5   30NHI4EO3U4MYQE43OHQZWIECDMBTK  Reviewable          3
# 31  3KQ8X25AA42TUG02UUXHJK449EG67C  Reviewable          3
# 22  3U9G08NWHX67DI1QKSR91HI45GLNCN  Reviewable          2
# 44  3K4OUUN0MMM1V0GQ8RC9O2T40Q0CM1  Reviewable          2
# 45  30MUBYSPBN3MCT5JK1PTOU5IXNGSKT  Reviewable          2
# 20  3K1KXTVNBJLH8X6SSUNP76ADWTIM1U  Reviewable          2
# 8   30CYSFZVFS451B6M9RY2L5G8M1ZO0G  Reviewable          1
# 32  3BHRGUFAI8X4TVTVSO8V0BSASE4CSX  Reviewable          1
# 3   39WEDTMWD5H8OLLUDF9NPBXRS14VX7  Reviewable          1
# 33  3MLGQ9U1F27F0UZONRPCX509WWWRJ4  Reviewable          1
# 7   34WBNEQO09S9IB1CZZCVZHHWOS6BRO  Reviewable          1
# 9   379YH0H8TKTH1O45K2S3B9TV1XJZSE  Reviewable          1
# 10  36NNBEP39C8GCBCI7Z5NRXFP8IVOHC  Reviewable          1
# 11  3ZBBW13US36INP3WAZ3998B9LYP9VE  Reviewable          1
# 12  3HR9SK23IR34FGXZK6XPHYJK00XR3H  Reviewable          1
# 13  35I9CFS6VH0U0WHK82R9I3GDR0Y5IA  Reviewable          1
# 14  36872VQHZ43ZX29NW72IMCSWU4H9MZ  Reviewable          1
# 15  38AOVEY0XVBXEAV19U1C958A8LQ43M  Reviewable          1
# 23  3ZYIH7REHEB580R45A22ZAZIRT01OR  Reviewable          1

# %%
our_hits = hits[hits.title.str.contains("Aligning Related Question-Answer Sets in ")][["title",'create_date',"hit_type", 'status','id', 'review_status','assign_available', 'assign_completed', 'assign_pending', 'MaxAssignments']]
our_hits
# Out:
#                                                 title  \
# 0   Aligning Related Question-Answer Sets in Sente...
# 1   Aligning Related Question-Answer Sets in Sente...
# 2   Aligning Related Question-Answer Sets in Sente...
# 3   Aligning Related Question-Answer Sets in Sente...
# 4   Aligning Related Question-Answer Sets in Sente...
# 5   Aligning Related Question-Answer Sets in Sente...
# 6   Aligning Related Question-Answer Sets in Sente...
# 7   Aligning Related Question-Answer Sets in Sente...
# 8   Aligning Related Question-Answer Sets in Sente...
# 9   Aligning Related Question-Answer Sets in Sente...
# 10  Aligning Related Question-Answer Sets in Sente...
# 11  Aligning Related Question-Answer Sets in Sente...
# 12  Aligning Related Question-Answer Sets in Sente...
# 13  Aligning Related Question-Answer Sets in Sente...
# 14  Aligning Related Question-Answer Sets in Sente...
# 15  Aligning Related Question-Answer Sets in Sente...
# 16  Aligning Related Question-Answer Sets in Sente...
# 17  Aligning Related Question-Answer Sets in Sente...
# 18  Aligning Related Question-Answer Sets in Sente...
# 19  Aligning Related Question-Answer Sets in Sente...
# 20  Aligning Related Question-Answer Sets in Sente...
# 21  Aligning Related Question-Answer Sets in Sente...
# 22  Aligning Related Question-Answer Sets in Sente...
# 23  Aligning Related Question-Answer Sets in Sente...
# 24  Aligning Related Question-Answer Sets in Sente...
# 25  Aligning Related Question-Answer Sets in Sente...
# 26  Aligning Related Question-Answer Sets in Sente...
# 27  Aligning Related Question-Answer Sets in Sente...
# 28  Aligning Related Question-Answer Sets in Sente...
# 29  Aligning Related Question-Answer Sets in Sente...
# 30  Aligning Related Question-Answer Sets in Sente...
# 31  Aligning Related Question-Answer Sets in Sente...
# 32  Aligning Related Question-Answer Sets in Sente...
# 33  Aligning Related Question-Answer Sets in Sente...
# 34  Aligning Related Question-Answer Sets in Sente...
# 35  Aligning Related Question-Answer Sets in Sente...
# 36  Aligning Related Question-Answer Sets in Sente...
# 37  Aligning Related Question-Answer Sets in Sente...
# 38  Aligning Related Question-Answer Sets in Sente...
#
#                  create_date                        hit_type      status  \
# 0  2021-02-18 00:37:03+02:00  3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable
# 1  2021-02-18 00:37:02+02:00  3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable
# 2  2021-02-18 00:37:02+02:00  3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable
# 3  2021-02-18 00:37:02+02:00  3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable
# 4  2021-02-18 00:37:02+02:00  3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable
# 5  2021-02-18 00:37:02+02:00  3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable
# 6  2021-02-18 00:37:02+02:00  3ARIN4O78FIM2TA9EE4I4F7QGZ8IFC  Assignable
# 7  2021-02-13 20:32:41+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 8  2021-02-13 20:32:41+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 9  2021-02-13 20:32:41+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 10 2021-02-13 20:32:41+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 11 2021-02-13 20:32:41+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 12 2021-02-13 20:32:40+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 13 2021-02-13 20:32:40+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 14 2021-02-13 20:32:40+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 15 2021-02-11 08:22:58+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 16 2021-02-11 08:22:58+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 17 2021-02-11 08:22:58+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 18 2021-02-11 08:22:58+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 19 2021-02-11 08:22:57+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 20 2021-02-11 08:22:57+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 21 2021-02-11 08:22:57+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 22 2021-02-11 08:22:57+02:00  3JUV1CRER4OK2UI2F0TQLNM9M6BW2N  Reviewable
# 23 2021-02-09 22:32:27+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 24 2021-02-09 22:32:27+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 25 2021-02-09 22:32:27+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 26 2021-02-09 22:32:27+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 27 2021-02-09 22:32:27+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 28 2021-02-09 22:32:27+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 29 2021-02-09 22:32:26+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 30 2021-02-09 22:32:26+02:00  3F1QRTWYOOIUSLZA47TJLG6Y3EWLYU  Reviewable
# 31 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 32 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 33 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 34 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 35 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 36 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 37 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
# 38 2021-02-08 23:11:22+02:00  3ES1UQ6TFXNUY4AWL458RLJRU3FLMZ  Reviewable
#
#                                 id review_status  assign_available  \
# 0   37SQU136V7P0NHBK6GYA3ZUJ7FB11R   NotReviewed                12
# 1   3VDI8GSXAFUF2WL8NKSSPWLXNA08GI   NotReviewed                12
# 2   3P7QK0GJ3TM47YEOXV7G0CO0C01Z2U   NotReviewed                11
# 3   38O9DZ0A62O2JOUDVQA53EV57W562B   NotReviewed                11
# 4   39WICJI5ATTTSGA71VLLJMTSIE1Z35   NotReviewed                12
# 5   382GHPVPHSSDPJMIG2VVPQGJHJZ43Z   NotReviewed                12
# 6   3X52SWXE0X6DBL1LJ1CFDL347PAWCA   NotReviewed                10
# 7   32ZCLEW0BZLAZQAQH7F68V8347CPJ8   NotReviewed                 5
# 8   3ZLW647WALW3M57VCOC7WBJLX0Z23N   NotReviewed                 6
# 9   3UUSLRKAUL48QY6YBPZE5BM5ZTA7D6   NotReviewed                 6
# 10  30P8I9JKOIMFXBS1EHKBDDEG8UIV5D   NotReviewed                 6
# 11  3FW4EL5A3LPE1NBC8OY2D1ETRMZ22C   NotReviewed                 5
# 12  38XPGNCKHT1X1SO10C118L828YNV48   NotReviewed                 5
# 13  32L724R85LLE4FQKZPU6WUT3RSNPIW   NotReviewed                 5
# 14  3XEIP58NL0OA8K0W71PLF8N9IVOZL5   NotReviewed                 5
# 15  3HEM8MA6H9DRLDE3CXZF5WKPHV3PQJ   NotReviewed                 0
# 16  39KV3A5D188ESNPG8FU30A85ZPIS74   NotReviewed                 0
# 17  3QI9WAYOGQCVONBBP5PBUW894EYS65   NotReviewed                 0
# 18  3B623HUYJ4RIS1UZIKM9EA40A9OS8R   NotReviewed                 0
# 19  32TZXEA1OLLHFG83TYHC1X1MING41D   NotReviewed                 0
# 20  3ODOP6T3ASLO41QZC2HQ6GBRATU42U   NotReviewed                 0
# 21  3R5LWXWHR095HXMGVS4K5V2QD73XGK   NotReviewed                 0
# 22  3JU8CV4BRLDO011NXK7BGRPP2ULPOB   NotReviewed                 0
# 23  3BO3NEOQM0I7HBKIA6C96Z48RXVAIQ   NotReviewed                 0
# 24  37OPIVELUU47LG9Y4OUO6N3TRKGAHX   NotReviewed                 0
# 25  3RIHDBQ1NEZ8NHIN1RKTFEYTL15MHT   NotReviewed                 0
# 26  37G6BXQPLQMNOMPD3JJ4BKLL3MAEQS   NotReviewed                 0
# 27  3126F2F5F842OAOY364FBFVBYQOPEC   NotReviewed                 0
# 28  3DFYDSXB2W1NRVIMYTE0I1V2BFCJUN   NotReviewed                 0
# 29  3QXFBUZ4ZKHD0TSLQNTXLO3MJNVUGU   NotReviewed                 0
# 30  3UEBBGULPFP7MTWQF3NF333AI8VUFV   NotReviewed                 0
# 31  34KYK9TV2R91UZS6LW6J5CU1ICPSB0   NotReviewed                11
# 32  3DWNFENNE3WOAXO7JNNI5XX8C1W4JR   NotReviewed                12
# 33  34D9ZRXCYRVWBPNEFI6NA1AV0U4SA5   NotReviewed                11
# 34  307FVKVSYRGVQ2N5IEYL27SZL6W74N   NotReviewed                12
# 35  3L21G7IH47XXDNMNI55JHM5TDLV1Y5   NotReviewed                12
# 36  3D06DR5225KTDUA9VLA1YSBP85MMAN   NotReviewed                12
# 37  33NKDW9FFXJS0L6BT681F4HBFCRXCK   NotReviewed                12
# 38  3SZYX62S5G1DMLR5WJHV7ZYDL2R75S   NotReviewed                 9
#
#     assign_completed  assign_pending  MaxAssignments
# 0                  0               0              12
# 1                  0               0              12
# 2                  0               0              12
# 3                  0               0              12
# 4                  0               0              12
# 5                  0               0              12
# 6                  0               1              12
# 7                  1               0               6
# 8                  0               0               6
# 9                  0               0               6
# 10                 0               0               6
# 11                 1               0               6
# 12                 1               0               6
# 13                 1               0               6
# 14                 1               0               6
# 15                12               0              12
# 16                12               0              12
# 17                12               0              12
# 18                12               0              12
# 19                12               0              12
# 20                12               0              12
# 21                12               0              12
# 22                12               0              12
# 23                12               0              12
# 24                12               0              12
# 25                12               0              12
# 26                12               0              12
# 27                12               0              12
# 28                12               0              12
# 29                12               0              12
# 30                12               0              12
# 31                 7               0              18
# 32                 6               0              18
# 33                 7               0              18
# 34                 6               0              18
# 35                 6               0              18
# 36                 6               0              18
# 37                 6               0              18
# 38                 9               0              18

# %%
mturk.list_assignments_for_hit(HITId="3DA79LNS59WX6418V3W5BUQ8WN0T3F")
# Out:
# {'NumResults': 0,
#  'Assignments': [],
#  'ResponseMetadata': {'RequestId': 'd58a89bb-bcd6-4ae3-a227-360067db17b0',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd58a89bb-bcd6-4ae3-a227-360067db17b0',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '33',
#    'date': 'Sun, 10 Jan 2021 16:30:00 GMT'},
#   'RetryAttempts': 0}}

# %%
def expire(hit_id):
    distant_past = datetime(year=2000, month=1, day=1)    
    resp = mturk.update_expiration_for_hit(HITId=hit_id, ExpireAt=distant_past)
    check_response(resp)
        
def delete(hit_id):
    resp = mturk.delete_hit(HITId=hit_id)
    check_response(resp)

# %%
our_hits[(our_hits.hit_type == GEN) & (our_hits.assign_pending != 0)]
# Out:
# Empty DataFrame
# Columns: [title, hit_type, status, id, review_status, assign_available, assign_completed, assign_pending, MaxAssignments]
# Index: []

# %% [markdown]
# ### Deleting hits

# %%
#to_expire = our_hits[(our_hits.hit_type == GEN) & ( hits.status != "Unassignable")].id
to_expire = our_hits[(our_hits.hit_type == QA_ALING)].id
print(len(to_expire))
for id_to_exp in to_expire:
    print(id_to_exp)
    expire(id_to_exp)
    print("deleting...")
    delete(id_to_exp)

# %% [markdown]
# ### Approving these assignments

# %%
mturk.approve_assignment(AssignmentId="3VAOOVPI3ZTQ3VJSS0YELPA82U7LLG")

# %%
# Out:
# /Users/danielastepanov/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 3IJ95K7NDXD0538CTMHB7TBSSQTGNU
# deleting...
# 3B9XR6P1WEW8VW9GY2X5DB3E3TWJBC
# deleting...

# %% [markdown]
# ## Sending email to workers

# %%
'''
trap_workers = ["A98E8M4QLI9RS",
"AZLZA0Q87TJZO",
"A2Q3FS9G8ITCN7",
"A1FS8SBR4SDWYG",
"A3B7TNVOISSZ2O",
"A21LONLNBOB8Q",
"A2EJ7U3TZAKROG",
"A1SX8IVV82M0LW",
"A3TUJHF9LW3M8N",
"A156E3IYUJ5CKK",
"A21X60VQIDZU4D",
"A3VBNWON5XOUVS",
"A2XWQY45UB1XQ6"]'''
more_trap_ppl = ['A3IQRBKS1DUJVZ']

# %%
me = ['A175DRQDVKWQA7']

# %%
response = mturk.notify_workers(
    Subject='We\'d like to invite you to participate in further training of our task!',
    MessageText='Hello,\n\n\
\
We were happy with your performance on the task: "Aligning Question-Answer Sets",\n\
where you had to read two sentences carefully, and align question-answer statements that expressed the same meaning.\n\
This task is used for research on information consolidation, which will hopefully aid in summarization research and other important language understanding tasks.\n\n\
\
Because this task is semantically challenging and non-trivial, we require workers who choose to continue with us to do large-scale annotations, to first go through a 30 minute reading of guidelines, and a 2 to 3 training rounds with feedback for every round. \n\
Those who finish the complete trainings will receive a 5$ bonus upon finishing this process, and will go on to annotate larger-scale annotations.\n\n\
\
Those that perform well and listen to feedbacks in training will continue on to large-scale annotation batches.\n\
If you are interested in this task and would like to start training, please reply to this email with your confirmation (plus your WorkerId).\n\n\
 \
We look forward to hearing from you, \n\
The Language and Understanding Lab',
    WorkerIds=more_trap_ppl
)

# %%
response
# Out:
# {'NotifyWorkersFailureStatuses': [],
#  'ResponseMetadata': {'RequestId': 'd3debbe2-bd8a-4c2d-9c07-ec7f845edf78',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd3debbe2-bd8a-4c2d-9c07-ec7f845edf78',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '35',
#    'date': 'Sun, 14 Feb 2021 10:21:50 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Paying bonuses to QASRL workers

# %%
def calculate_who_needs_bonus(GEN):
    import re
    import json
    qs_to_bonus = []
    for hit_id in hits[hits.hit_type == GEN].id.tolist():    
        assigns = mturk.list_assignments_for_hit(HITId=hit_id)["Assignments"]
        approved_assigns = [a for a in assigns if a['AssignmentStatus'] == "Approved"]
        for a in approved_assigns:
            xml_answer = a['Answer']
            #         best xml parsing ever

            free_text = re.findall(r"<FreeText>(.*)</FreeText>", xml_answer)[0]
            try:
                free_json = json.loads(free_text)
            except:
                # PEOPLE WITH FEEDBACK UGGGH
                print(free_text)            
            n_questions = len(free_json)
            qs_to_bonus.append({'worker_id': a['WorkerId'], "n_questions": n_questions})
    df = pd.DataFrame(qs_to_bonus).sort_values("worker_id")
    return df

# %%
df_for_bonus = calculate_who_needs_bonus('37AIU3VBY7PGVE4D4V4DOE8O6YDXR7')

# %%
df_for_bonus

# %%
def generationBonus(numQs):
    # no bonus for the first question, hence -1
    accum_cents = 5 #cents
    total_cents = sum([accum_cents+i for i in range(numQs-1)])
    return total_cents

# %%
df_for_bonus['bonus_cents'] = df_for_bonus['n_questions'].apply(lambda x: generationBonus(x))

# %% [markdown]
# ### Amount to pay for trap in bonuses

# %%
df_for_bonus.groupby("worker_id").sum()
# Out:
#                 n_questions  bonus_cents
# worker_id
# A21LONLNBOB8Q            52          199
# A3TUJHF9LW3M8N           48          172

# %%
df_for_bonus.bonus_cents.mean()
# Out:
# 12.483516483516484

# %%
df_for_bonus[df_for_bonus.worker_id == 'A3TUJHF9LW3M8N'].sum()
# Out:
# worker_id      A3TUJHF9LW3M8NA3TUJHF9LW3M8NA3TUJHF9LW3M8NA3TU...
# n_questions                                                   48
# bonus_cents                                                  172
# dtype: object
